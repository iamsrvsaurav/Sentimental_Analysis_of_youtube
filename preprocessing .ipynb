# %%
import pandas as pd

# %%
df=pd.read_csv("final_dataset")

# %%
df.head()
# Out:
#    Unnamed: 0                                            comment
# 0           0  🔥 Want to master Python? Get my complete Pytho...
# 1           1  I'm learning because i want a better job than ...
# 2           2  Thanks Mosh! ❤ After struggling for 1 year wit...
# 3           3  0:00:00 Introduction \r\n0:00:30 What You Can ...
# 4           4  Ik he won’t see this, but this was such a clea...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#                                              comment
# 0  🔥 Want to master Python? Get my complete Pytho...
# 1  I'm learning because i want a better job than ...
# 2  Thanks Mosh! ❤ After struggling for 1 year wit...
# 3  0:00:00 Introduction \r\n0:00:30 What You Can ...
# 4  Ik he won’t see this, but this was such a clea...

# %%
import nltk
import pandas as pd
from nltk.stem import PorterStemmer
import re

# %%
def preprocesing(comment):
    # remove html markup
    comment=re.sub("(<.*?>)","",comment)
#     # Remove Emails
#     comment = re.sub('\S*@\S*\s?', '', comment)
    #remove non-ascii and digits
    comment=re.sub("(\\W|\\d)"," ",comment)
    
    stopwords=['this','that','and','a','we','it','to','is','of','up','need']
    porter_stemmer=PorterStemmer()
    words=comment.split()
    res=[]
    for i in range(len(words)):
        if words[i].lower() not  in stopwords :#Stop Word Removal
            #Lowercasing
            res.append(words[i].lower())
            #Stemming
            res[-1]=porter_stemmer.stem(word=res[-1])
    
    return " ".join(res)

# %%
df["final"]=df["comment"].apply(preprocesing)

# %%
df.head(50)
# Out:
#                                               comment  \
# 0   🔥 Want to master Python? Get my complete Pytho...
# 1   I'm learning because i want a better job than ...
# 2   Thanks Mosh! ❤ After struggling for 1 year wit...
# 3   0:00:00 Introduction \r\n0:00:30 What You Can ...
# 4   Ik he won’t see this, but this was such a clea...
# 5   This was very nice jumping in from the standpo...
# 6   As I was following along, there's an important...
# 7   I'm literally only like 5 minutes in and this ...
# 8   Yes, Mosh is teaching python here too. But mor...
# 9   I use to always fail my coding classes, but yo...
# 10  Haven't used python since I graduated 2 years ...
# 11  Love the simplicity & wisdom with which you te...
# 12  Even as someone with a history of coding, the ...
# 13  This guy, sat for 1 hour and talked about pyth...
# 14  Thanks! This is better than any other tutorial...
# 15  You're the Man, thank you Mosh. I'm still a to...
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     831                 sock.bind(source_address)
# --> 832             sock.connect(sa)
#     833             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1096\3314422247.py in <module>
#       1 import nltk
# ----> 2 nltk.download('vader_lexicon')
#
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
def getsentiments(comment):
    # instantiate analyzer
    analyzer = SentimentIntensityAnalyzer()
    if analyzer.polarity_scores(comment)['compound'] >= 0.0: 
        return 1 # positive sentiment
#     elif analyzer.polarity_scores(comment)['compound'] < -0.2:
#         return 1 # negative sentiment
    else:
        return 2 # neutral sentiment

# %%
print(getsentiments(" i am feeling bored about today"))
print(getsentiments(" i am feeling bad about today"))
print(getsentiments(" i am feeling excited  about today"))
# Out:
# 2
# 2
# 1

# %%
df["sentiments"]=df["comment"].apply(getsentiments)

# %%
df.head()
# Out:
#                                              comment  \
# 0  🔥 Want to master Python? Get my complete Pytho...
# 1  I'm learning because i want a better job than ...
# 2  Thanks Mosh! ❤ After struggling for 1 year wit...
# 3  0:00:00 Introduction \r\n0:00:30 What You Can ...
# 4  Ik he won’t see this, but this was such a clea...
#
#                                                final  sentiments
# 0  want master python get my complet python cours...           1
# 1  i m learn becaus i want better job than drive ...           1
# 2  thank mosh after struggl for year with complic...           1
# 3  introduct what you can do with python your fir...           1
# 4  ik he won t see but wa such clear display how ...           1

# %%
df["sentiments"].value_counts()
# Out:
# 1    6283
# 2     679
# Name: sentiments, dtype: int64

# %%
df.drop("comment",axis=1,inplace=True)

# %%
df.to_csv("trainingdataset.csv",index=False)
